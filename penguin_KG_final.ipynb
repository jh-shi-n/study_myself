# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %%
# 데이터 불러오기
data_ = pd.read_csv("./train.csv")
test_df = pd.read_csv("./test.csv")

data_
# 수치형 데이터 및 문자열데이터가 섞인것 확인
# Out:
#       id                                    Species     Island  \
# 0      0          Gentoo penguin (Pygoscelis papua)     Biscoe
# 1      1  Chinstrap penguin (Pygoscelis antarctica)      Dream
# 2      2          Gentoo penguin (Pygoscelis papua)     Biscoe
# 3      3          Gentoo penguin (Pygoscelis papua)     Biscoe
# 4      4          Gentoo penguin (Pygoscelis papua)     Biscoe
# ..   ...                                        ...        ...
# 109  109        Adelie Penguin (Pygoscelis adeliae)  Torgersen
# 110  110        Adelie Penguin (Pygoscelis adeliae)      Dream
# 111  111        Adelie Penguin (Pygoscelis adeliae)      Dream
# 112  112  Chinstrap penguin (Pygoscelis antarctica)      Dream
# 113  113          Gentoo penguin (Pygoscelis papua)     Biscoe
#
#     Clutch Completion  Culmen Length (mm)  Culmen Depth (mm)  \
# 0                 Yes                50.0               15.3
# 1                  No                49.5               19.0
# 2                 Yes                45.1               14.4
# 3                 Yes                44.5               14.7
# 4                  No                49.6               16.0
# ..                ...                 ...                ...
# 109               Yes                36.6               17.8
# 110               Yes                39.2               18.6
# 111               Yes                43.2               18.5
# 112                No                46.9               16.6
# 113               Yes                50.8               17.3
#
#      Flipper Length (mm)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0                    220    MALE            8.30515          -25.19017
# 1                    200    MALE            9.63074          -24.34684
# 2                    210  FEMALE            8.51951          -27.01854
# 3                    214  FEMALE            8.20106          -26.16524
# 4                    225    MALE            8.38324          -26.84272
# ..                   ...     ...                ...                ...
# 109                  185  FEMALE                NaN                NaN
# 110                  190    MALE            9.11006          -25.79549
# 111                  192    MALE            8.97025          -26.03679
# 112                  192  FEMALE            9.80589          -24.73735
# 113                  228    MALE            8.27428          -26.30019
#
#      Body Mass (g)
# 0             5550
# 1             3800
# 2             4400
# 3             4850
# 4             5700
# ..             ...
# 109           3700
# 110           4250
# 111           4100
# 112           2700
# 113           5600
#
# [114 rows x 11 columns]

# %%
# 데이터 결측치 갯수 확인
print(data_.isnull().sum(), "\n","___________", "\n",test_df.isnull().sum())
# Out:
# id                     0
# Species                0
# Island                 0
# Clutch Completion      0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Sex                    3
# Delta 15 N (o/oo)      3
# Delta 13 C (o/oo)      3
# Body Mass (g)          0
# dtype: int64
#  ___________
#  id                     0
# Species                0
# Island                 0
# Clutch Completion      0
# Culmen Length (mm)     0
# Culmen Depth (mm)      0
# Flipper Length (mm)    0
# Sex                    6
# Delta 15 N (o/oo)      9
# Delta 13 C (o/oo)      8
# dtype: int64

# %%
### 데이터 전처리
## 문자열 데이터 더미화
sub = pd.get_dummies(data_[['Species', 'Island', 'Sex', 'Clutch Completion']])
data_first = pd.concat([sub ,data_.iloc[:,4:7], data_.iloc[:,8:]], axis=1)

# %%
# 상관계수 확인, id는 활용 안할 예정이기때문에 제외 후 확인
data_first.corr()
# Out:
#                                                    Species_Adelie Penguin (Pygoscelis adeliae)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                                           1.000000
# Species_Chinstrap penguin (Pygoscelis antarctica)                                    -0.397197
# Species_Gentoo penguin (Pygoscelis papua)                                            -0.639115
# Island_Biscoe                                                                        -0.420411
# Island_Dream                                                                          0.119228
# Island_Torgersen                                                                      0.478719
# Sex_FEMALE                                                                           -0.065138
# Sex_MALE                                                                              0.031431
# Clutch Completion_No                                                                 -0.078370
# Clutch Completion_Yes                                                                 0.078370
# Culmen Length (mm)                                                                   -0.820508
# Culmen Depth (mm)                                                                     0.522864
# Flipper Length (mm)                                                                  -0.688047
# Delta 15 N (o/oo)                                                                     0.172781
# Delta 13 C (o/oo)                                                                    -0.087580
# Body Mass (g)                                                                        -0.507076
#
#                                                    Species_Chinstrap penguin (Pygoscelis antarctica)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                                                -0.397197
# Species_Chinstrap penguin (Pygoscelis antarctica)                                           1.000000
# Species_Gentoo penguin (Pygoscelis papua)                                                  -0.451985
# Island_Biscoe                                                                              -0.529999
# Island_Dream                                                                                0.668494
# Island_Torgersen                                                                           -0.190145
# Sex_FEMALE                                                                                  0.082247
# Sex_MALE                                                                                   -0.054310
# Clutch Completion_No                                                                        0.301768
# Clutch Completion_Yes                                                                      -0.301768
# Culmen Length (mm)                                                                          0.377195
# Culmen Depth (mm)                                                                           0.378706
# Flipper Length (mm)                                                                        -0.253306
# Delta 15 N (o/oo)                                                                           0.648444
# Delta 13 C (o/oo)                                                                           0.760515
# Body Mass (g)                                                                              -0.389398
#
#                                                    Species_Gentoo penguin (Pygoscelis papua)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                                        -0.639115
# Species_Chinstrap penguin (Pygoscelis antarctica)                                  -0.451985
# Species_Gentoo penguin (Pygoscelis papua)                                           1.000000
# Island_Biscoe                                                                       0.852803
# Island_Dream                                                                       -0.676123
# Island_Torgersen                                                                   -0.305956
# Sex_FEMALE                                                                         -0.005614
# Sex_MALE                                                                            0.014964
# Clutch Completion_No                                                               -0.176724
# Clutch Completion_Yes                                                               0.176724
# Culmen Length (mm)                                                                  0.481414
# Culmen Depth (mm)                                                                  -0.825594
# Flipper Length (mm)                                                                 0.881057
# Delta 15 N (o/oo)                                                                  -0.712250
# Delta 13 C (o/oo)                                                                  -0.557381
# Body Mass (g)                                                                       0.819209
#
#                                                    Island_Biscoe  \
# Species_Adelie Penguin (Pygoscelis adeliae)            -0.420411
# Species_Chinstrap penguin (Pygoscelis antarctica)      -0.529999
# Species_Gentoo penguin (Pygoscelis papua)               0.852803
# Island_Biscoe                                           1.000000
# Island_Dream                                           -0.792825
# Island_Torgersen                                       -0.358766
# Sex_FEMALE                                              0.017555
# Sex_MALE                                                0.000000
# Clutch Completion_No                                   -0.228665
# Clutch Completion_Yes                                   0.228665
# Culmen Length (mm)                                      0.296513
# Culmen Depth (mm)                                      -0.724780
# Flipper Length (mm)                                     0.739562
# Delta 15 N (o/oo)                                      -0.644446
# Delta 13 C (o/oo)                                      -0.588510
# Body Mass (g)                                           0.708050
#
#                                                    Island_Dream  \
# Species_Adelie Penguin (Pygoscelis adeliae)            0.119228
# Species_Chinstrap penguin (Pygoscelis antarctica)      0.668494
# Species_Gentoo penguin (Pygoscelis papua)             -0.676123
# Island_Biscoe                                         -0.792825
# Island_Dream                                           1.000000
# Island_Torgersen                                      -0.284438
# Sex_FEMALE                                             0.027836
# Sex_MALE                                               0.013911
# Clutch Completion_No                                   0.315199
# Clutch Completion_Yes                                 -0.315199
# Culmen Length (mm)                                    -0.047199
# Culmen Depth (mm)                                      0.559757
# Flipper Length (mm)                                   -0.566061
# Delta 15 N (o/oo)                                      0.703095
# Delta 13 C (o/oo)                                      0.673803
# Body Mass (g)                                         -0.573564
#
#                                                    Island_Torgersen  \
# Species_Adelie Penguin (Pygoscelis adeliae)                0.478719
# Species_Chinstrap penguin (Pygoscelis antarctica)         -0.190145
# Species_Gentoo penguin (Pygoscelis papua)                 -0.305956
# Island_Biscoe                                             -0.358766
# Island_Dream                                              -0.284438
# Island_Torgersen                                           1.000000
# Sex_FEMALE                                                -0.070247
# Sex_MALE                                                  -0.021307
# Clutch Completion_No                                      -0.123056
# Clutch Completion_Yes                                      0.123056
# Culmen Length (mm)                                        -0.394139
# Culmen Depth (mm)                                          0.282796
# Flipper Length (mm)                                       -0.296392
# Delta 15 N (o/oo)                                         -0.068307
# Delta 13 C (o/oo)                                         -0.114119
# Body Mass (g)                                             -0.235331
#
#                                                    Sex_FEMALE  Sex_MALE  \
# Species_Adelie Penguin (Pygoscelis adeliae)         -0.065138  0.031431
# Species_Chinstrap penguin (Pygoscelis antarctica)    0.082247 -0.054310
# Species_Gentoo penguin (Pygoscelis papua)           -0.005614  0.014964
# Island_Biscoe                                        0.017555  0.000000
# Island_Dream                                         0.027836  0.013911
# Island_Torgersen                                    -0.070247 -0.021307
# Sex_FEMALE                                           1.000000 -0.948714
# Sex_MALE                                            -0.948714  1.000000
# Clutch Completion_No                                -0.102360  0.120368
# Clutch Completion_Yes                                0.102360 -0.120368
# Culmen Length (mm)                                  -0.294620  0.332699
# Culmen Depth (mm)                                   -0.364386  0.349191
# Flipper Length (mm)                                 -0.238123  0.252635
# Delta 15 N (o/oo)                                   -0.132672  0.135789
# Delta 13 C (o/oo)                                    0.102378 -0.092598
# Body Mass (g)                                       -0.405566  0.419098
#
#                                                    Clutch Completion_No  \
# Species_Adelie Penguin (Pygoscelis adeliae)                   -0.078370
# Species_Chinstrap penguin (Pygoscelis antarctica)              0.301768
# Species_Gentoo penguin (Pygoscelis papua)                     -0.176724
# Island_Biscoe                                                 -0.228665
# Island_Dream                                                   0.315199
# Island_Torgersen                                              -0.123056
# Sex_FEMALE                                                    -0.102360
# Sex_MALE                                                       0.120368
# Clutch Completion_No                                           1.000000
# Clutch Completion_Yes                                         -1.000000
# Culmen Length (mm)                                             0.119988
# Culmen Depth (mm)                                              0.210304
# Flipper Length (mm)                                           -0.105076
# Delta 15 N (o/oo)                                              0.277890
# Delta 13 C (o/oo)                                              0.291190
# Body Mass (g)                                                 -0.093065
#
#                                                    Clutch Completion_Yes  \
# Species_Adelie Penguin (Pygoscelis adeliae)                     0.078370
# Species_Chinstrap penguin (Pygoscelis antarctica)              -0.301768
# Species_Gentoo penguin (Pygoscelis papua)                       0.176724
# Island_Biscoe                                                   0.228665
# Island_Dream                                                   -0.315199
# Island_Torgersen                                                0.123056
# Sex_FEMALE                                                      0.102360
# Sex_MALE                                                       -0.120368
# Clutch Completion_No                                           -1.000000
# Clutch Completion_Yes                                           1.000000
# Culmen Length (mm)                                             -0.119988
# Culmen Depth (mm)                                              -0.210304
# Flipper Length (mm)                                             0.105076
# Delta 15 N (o/oo)                                              -0.277890
# Delta 13 C (o/oo)                                              -0.291190
# Body Mass (g)                                                   0.093065
#
#                                                    Culmen Length (mm)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                 -0.820508
# Species_Chinstrap penguin (Pygoscelis antarctica)            0.377195
# Species_Gentoo penguin (Pygoscelis papua)                    0.481414
# Island_Biscoe                                                0.296513
# Island_Dream                                                -0.047199
# Island_Torgersen                                            -0.394139
# Sex_FEMALE                                                  -0.294620
# Sex_MALE                                                     0.332699
# Clutch Completion_No                                         0.119988
# Clutch Completion_Yes                                       -0.119988
# Culmen Length (mm)                                           1.000000
# Culmen Depth (mm)                                           -0.251255
# Flipper Length (mm)                                          0.672205
# Delta 15 N (o/oo)                                           -0.040205
# Delta 13 C (o/oo)                                            0.114983
# Body Mass (g)                                                0.572063
#
#                                                    Culmen Depth (mm)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                 0.522864
# Species_Chinstrap penguin (Pygoscelis antarctica)           0.378706
# Species_Gentoo penguin (Pygoscelis papua)                  -0.825594
# Island_Biscoe                                              -0.724780
# Island_Dream                                                0.559757
# Island_Torgersen                                            0.282796
# Sex_FEMALE                                                 -0.364386
# Sex_MALE                                                    0.349191
# Clutch Completion_No                                        0.210304
# Clutch Completion_Yes                                      -0.210304
# Culmen Length (mm)                                         -0.251255
# Culmen Depth (mm)                                           1.000000
# Flipper Length (mm)                                        -0.603341
# Delta 15 N (o/oo)                                           0.650629
# Delta 13 C (o/oo)                                           0.477688
# Body Mass (g)                                              -0.490643
#
#                                                    Flipper Length (mm)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                  -0.688047
# Species_Chinstrap penguin (Pygoscelis antarctica)            -0.253306
# Species_Gentoo penguin (Pygoscelis papua)                     0.881057
# Island_Biscoe                                                 0.739562
# Island_Dream                                                 -0.566061
# Island_Torgersen                                             -0.296392
# Sex_FEMALE                                                   -0.238123
# Sex_MALE                                                      0.252635
# Clutch Completion_No                                         -0.105076
# Clutch Completion_Yes                                         0.105076
# Culmen Length (mm)                                            0.672205
# Culmen Depth (mm)                                            -0.603341
# Flipper Length (mm)                                           1.000000
# Delta 15 N (o/oo)                                            -0.533212
# Delta 13 C (o/oo)                                            -0.454315
# Body Mass (g)                                                 0.864814
#
#                                                    Delta 15 N (o/oo)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                 0.172781
# Species_Chinstrap penguin (Pygoscelis antarctica)           0.648444
# Species_Gentoo penguin (Pygoscelis papua)                  -0.712250
# Island_Biscoe                                              -0.644446
# Island_Dream                                                0.703095
# Island_Torgersen                                           -0.068307
# Sex_FEMALE                                                 -0.132672
# Sex_MALE                                                    0.135789
# Clutch Completion_No                                        0.277890
# Clutch Completion_Yes                                      -0.277890
# Culmen Length (mm)                                         -0.040205
# Culmen Depth (mm)                                           0.650629
# Flipper Length (mm)                                        -0.533212
# Delta 15 N (o/oo)                                           1.000000
# Delta 13 C (o/oo)                                           0.641107
# Body Mass (g)                                              -0.548678
#
#                                                    Delta 13 C (o/oo)  \
# Species_Adelie Penguin (Pygoscelis adeliae)                -0.087580
# Species_Chinstrap penguin (Pygoscelis antarctica)           0.760515
# Species_Gentoo penguin (Pygoscelis papua)                  -0.557381
# Island_Biscoe                                              -0.588510
# Island_Dream                                                0.673803
# Island_Torgersen                                           -0.114119
# Sex_FEMALE                                                  0.102378
# Sex_MALE                                                   -0.092598
# Clutch Completion_No                                        0.291190
# Clutch Completion_Yes                                      -0.291190
# Culmen Length (mm)                                          0.114983
# Culmen Depth (mm)                                           0.477688
# Flipper Length (mm)                                        -0.454315
# Delta 15 N (o/oo)                                           0.641107
# Delta 13 C (o/oo)                                           1.000000
# Body Mass (g)                                              -0.468425
#
#                                                    Body Mass (g)
# Species_Adelie Penguin (Pygoscelis adeliae)            -0.507076
# Species_Chinstrap penguin (Pygoscelis antarctica)      -0.389398
# Species_Gentoo penguin (Pygoscelis papua)               0.819209
# Island_Biscoe                                           0.708050
# Island_Dream                                           -0.573564
# Island_Torgersen                                       -0.235331
# Sex_FEMALE                                             -0.405566
# Sex_MALE                                                0.419098
# Clutch Completion_No                                   -0.093065
# Clutch Completion_Yes                                   0.093065
# Culmen Length (mm)                                      0.572063
# Culmen Depth (mm)                                      -0.490643
# Flipper Length (mm)                                     0.864814
# Delta 15 N (o/oo)                                      -0.548678
# Delta 13 C (o/oo)                                      -0.468425
# Body Mass (g)                                           1.000000

# %%
### 상관계수값이 0과 비슷한 상태인 Clutch completion를 제거

### Train 데이터를 다시 정리합니다.
## 문자열 데이터 더미화
sub = pd.get_dummies(data_[['Species', 'Island', 'Sex']])
data = pd.concat([sub ,data_.iloc[:,4:7], data_.iloc[:,8:]], axis=1)

## Delta 관련 데이터 보간
# 결측치 ~ 평균치를 통한 결측 대치
data['Delta 15 N (o/oo)'].fillna(data['Delta 15 N (o/oo)'].mean(), inplace=True)
data['Delta 13 C (o/oo)'].fillna(data['Delta 13 C (o/oo)'].mean(), inplace=True)

data
# Out:
#      Species_Adelie Penguin (Pygoscelis adeliae)  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ..                                           ...
# 109                                            1
# 110                                            1
# 111                                            1
# 112                                            0
# 113                                            0
#
#      Species_Chinstrap penguin (Pygoscelis antarctica)  \
# 0                                                    0
# 1                                                    1
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 109                                                  0
# 110                                                  0
# 111                                                  0
# 112                                                  1
# 113                                                  0
#
#      Species_Gentoo penguin (Pygoscelis papua)  Island_Biscoe  Island_Dream  \
# 0                                            1              1             0
# 1                                            0              0             1
# 2                                            1              1             0
# 3                                            1              1             0
# 4                                            1              1             0
# ..                                         ...            ...           ...
# 109                                          0              0             0
# 110                                          0              0             1
# 111                                          0              0             1
# 112                                          0              0             1
# 113                                          1              1             0
#
#      Island_Torgersen  Sex_FEMALE  Sex_MALE  Culmen Length (mm)  \
# 0                   0           0         1                50.0
# 1                   0           0         1                49.5
# 2                   0           1         0                45.1
# 3                   0           1         0                44.5
# 4                   0           0         1                49.6
# ..                ...         ...       ...                 ...
# 109                 1           1         0                36.6
# 110                 0           0         1                39.2
# 111                 0           0         1                43.2
# 112                 0           1         0                46.9
# 113                 0           0         1                50.8
#
#      Culmen Depth (mm)  Flipper Length (mm)  Delta 15 N (o/oo)  \
# 0                 15.3                  220           8.305150
# 1                 19.0                  200           9.630740
# 2                 14.4                  210           8.519510
# 3                 14.7                  214           8.201060
# 4                 16.0                  225           8.383240
# ..                 ...                  ...                ...
# 109               17.8                  185           8.737634
# 110               18.6                  190           9.110060
# 111               18.5                  192           8.970250
# 112               16.6                  192           9.805890
# 113               17.3                  228           8.274280
#
#      Delta 13 C (o/oo)  Body Mass (g)
# 0           -25.190170           5550
# 1           -24.346840           3800
# 2           -27.018540           4400
# 3           -26.165240           4850
# 4           -26.842720           5700
# ..                 ...            ...
# 109         -25.723051           3700
# 110         -25.795490           4250
# 111         -26.036790           4100
# 112         -24.737350           2700
# 113         -26.300190           5600
#
# [114 rows x 14 columns]

# %%
# 데이터 train, test 분류
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=44)

# %% [markdown]
# # 다양한 머신러닝 모델을 활용하여 Score 도출

# %%
model = Ridge().fit(x_train, y_train)
print(f'Ridge: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = Lasso().fit(x_train, y_train)
print(f'Lasso: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = DecisionTreeRegressor().fit(x_train, y_train)
print(f'DT: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')
 
model = RandomForestRegressor().fit(x_train, y_train)
print(f'RF: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = GradientBoostingRegressor().fit(x_train, y_train)
print(f'GBR: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = KNeighborsRegressor(n_neighbors=5).fit(x_train, y_train)
print(f'KNR: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = LinearRegression().fit(x_train, y_train)
print(f'Linear: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = XGBRegressor().fit(x_train, y_train)
print(f'XGB: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')

model = LGBMRegressor().fit(x_train, y_train)
print(f'LGBM: Train 데이터 점수: {model.score(x_train, y_train)}, Val 데이터 점수: {model.score(x_test, y_test)}')
# Out:
# Ridge: Train 데이터 점수: 0.8641017638326064, Val 데이터 점수: 0.8059839531882603
# Lasso: Train 데이터 점수: 0.8658686724666305, Val 데이터 점수: 0.8095835720321577
# DT: Train 데이터 점수: 1.0, Val 데이터 점수: 0.5346657224934208
# RF: Train 데이터 점수: 0.973159273173338, Val 데이터 점수: 0.7473022969023082
# GBR: Train 데이터 점수: 0.9924930393666737, Val 데이터 점수: 0.6680128371057553
# KNR: Train 데이터 점수: 0.8519574669303234, Val 데이터 점수: 0.7141598866992105
# Linear: Train 데이터 점수: 0.8660014872647775, Val 데이터 점수: 0.8166067602935926
# XGB: Train 데이터 점수: 0.9999999987317032, Val 데이터 점수: 0.6865729233842979
# LGBM: Train 데이터 점수: 0.9007730007239413, Val 데이터 점수: 0.7642398373471202

# %% [markdown]
# #### Linear 모델의 val 데이터 점수가 타 모델에 비해 가장 높은 모습을 보여줌

# %% [markdown]
# # 선정한 Linear 모델의 RMSE 결과 확인

# %%
model = LinearRegression().fit(x_train, y_train)
y_pred = model.predict(x_test)

print(mean_squared_error(y_pred, y_test)**0.5)
# Out:
# 293.7459661364062

# %% [markdown]
# # Test_data로 제출파일 생성

# %%
# 제출파일 미리 불러오기
submit_df = pd.read_csv("./sample_submission.csv")

# testdata도 기존 방법과 같이 똑같이 전처리 진행 후 predict
sub = pd.get_dummies(test_df[['Species', 'Island', 'Sex']])
data_t = pd.concat([sub,test_df.iloc[:,4:7], test_df.iloc[:,8:]], axis=1)

data_t['Delta 15 N (o/oo)'].fillna(data_t['Delta 15 N (o/oo)'].mean(), inplace=True)
data_t['Delta 13 C (o/oo)'].fillna(data_t['Delta 13 C (o/oo)'].mean(), inplace=True)

# %%
data_t
# Out:
#      Species_Adelie Penguin (Pygoscelis adeliae)  \
# 0                                              0
# 1                                              0
# 2                                              1
# 3                                              0
# 4                                              1
# ..                                           ...
# 223                                            0
# 224                                            0
# 225                                            0
# 226                                            0
# 227                                            1
#
#      Species_Chinstrap penguin (Pygoscelis antarctica)  \
# 0                                                    1
# 1                                                    0
# 2                                                    0
# 3                                                    1
# 4                                                    0
# ..                                                 ...
# 223                                                  1
# 224                                                  0
# 225                                                  0
# 226                                                  1
# 227                                                  0
#
#      Species_Gentoo penguin (Pygoscelis papua)  Island_Biscoe  Island_Dream  \
# 0                                            0              0             1
# 1                                            1              1             0
# 2                                            0              0             1
# 3                                            0              0             1
# 4                                            0              1             0
# ..                                         ...            ...           ...
# 223                                          0              0             1
# 224                                          1              1             0
# 225                                          1              1             0
# 226                                          0              0             1
# 227                                          0              1             0
#
#      Island_Torgersen  Sex_FEMALE  Sex_MALE  Culmen Length (mm)  \
# 0                   0           0         1                52.0
# 1                   0           0         1                55.9
# 2                   0           1         0                38.9
# 3                   0           1         0                45.2
# 4                   0           1         0                37.9
# ..                ...         ...       ...                 ...
# 223                 0           0         1                49.3
# 224                 0           1         0                46.5
# 225                 0           1         0                46.5
# 226                 0           0         1                50.5
# 227                 0           0         1                37.6
#
#      Culmen Depth (mm)  Flipper Length (mm)  Delta 15 N (o/oo)  \
# 0                 20.7                210.0            9.43146
# 1                 17.0                228.0            8.31180
# 2                 18.8                190.0            8.36936
# 3                 16.6                191.0            9.62357
# 4                 18.6                172.0            8.38404
# ..                 ...                  ...                ...
# 223               19.9                203.0            9.88809
# 224               14.8                217.0            8.58487
# 225               13.5                210.0            7.99530
# 226               19.6                201.0            9.80590
# 227               19.1                194.0            9.10800
#
#      Delta 13 C (o/oo)
# 0            -24.68440
# 1            -26.35425
# 2            -26.11199
# 3            -24.78984
# 4            -25.19837
# ..                 ...
# 223          -24.59513
# 224          -26.59290
# 225          -25.32829
# 226          -24.72940
# 227          -25.89677
#
# [228 rows x 13 columns]

# %%
# Test 데이터 예측 전 열 최종 확인
print(data_t.isnull().sum())

# test 데이터 예측
test_pred = model.predict(data_t)
# Out:
# Species_Adelie Penguin (Pygoscelis adeliae)          0
# Species_Chinstrap penguin (Pygoscelis antarctica)    0
# Species_Gentoo penguin (Pygoscelis papua)            0
# Island_Biscoe                                        0
# Island_Dream                                         0
# Island_Torgersen                                     0
# Sex_FEMALE                                           0
# Sex_MALE                                             0
# Culmen Length (mm)                                   0
# Culmen Depth (mm)                                    0
# Flipper Length (mm)                                  0
# Delta 15 N (o/oo)                                    0
# Delta 13 C (o/oo)                                    0
# dtype: int64

# %%
# 제출
submit_df['Body Mass (g)'] = test_pred
submit_df.to_csv("./sample_submission_저장.csv", index=False)
