# %%
## if Use Colab
# from pycaret.utils import enable_colab
# enable_colab()

# %%
from pycaret.classification import *
from pycaret.regression import *
from pycaret.datasets import get_data

# %%
dataset = get_data('diamond')
#dataset.shape = (6000, 8)
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
#데이터 준비
data = dataset.sample(frac=0.9, random_state=786) 
data_unseen = dataset.drop(data.index) 
data.reset_index(drop=True, inplace=True) 
data_unseen.reset_index(drop=True, inplace=True) 
print('Data for Modeling: ' + str(data.shape)) 
print('Unseen Data For Predictions: ' + str(data_unseen.shape)) # Data for Modeling: (5400, 8) # Unseen Data For Predictions: (600, 8)
# Out:
# Data for Modeling: (5400, 8)
# Unseen Data For Predictions: (600, 8)

# %%
# 모델 환경설정
exp_reg001 = setup(data = data, target = 'Price', session_id=123)
# Out:
# <style type="text/css">
# #T_fad53_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fad53_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fad53_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fad53_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_fad53_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fad53_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fad53_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fad53_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_fad53_row2_col1" class="data row2 col1" >(5400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fad53_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_fad53_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fad53_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_fad53_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fad53_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_fad53_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fad53_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_fad53_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fad53_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_fad53_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fad53_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_fad53_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fad53_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_fad53_row9_col1" class="data row9 col1" >(3779, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fad53_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_fad53_row10_col1" class="data row10 col1" >(1621, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fad53_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_fad53_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fad53_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_fad53_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fad53_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_fad53_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fad53_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_fad53_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fad53_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_fad53_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fad53_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_fad53_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fad53_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_fad53_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fad53_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_fad53_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fad53_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_fad53_row19_col1" class="data row19 col1" >6993</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fad53_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_fad53_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_fad53_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_fad53_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_fad53_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_fad53_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_fad53_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_fad53_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_fad53_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_fad53_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_fad53_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_fad53_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_fad53_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_fad53_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_fad53_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_fad53_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_fad53_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_fad53_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_fad53_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_fad53_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fad53_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_fad53_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_fad53_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr>

# %%
# 데이터에 대한 모델 추천 실행
best = compare_models(exclude=['ransac'])
# Out:
# <style type="text/css">
# #T_db20b_ th {
#   text-align: left;
# }
# #T_db20b_row0_col0, #T_db20b_row0_col1, #T_db20b_row0_col3, #T_db20b_row0_col5, #T_db20b_row0_col6, #T_db20b_row1_col0, #T_db20b_row1_col2, #T_db20b_row1_col4, #T_db20b_row2_col0, #T_db20b_row2_col1, #T_db20b_row2_col2, #T_db20b_row2_col3, #T_db20b_row2_col4, #T_db20b_row2_col5, #T_db20b_row2_col6, #T_db20b_row3_col0, #T_db20b_row3_col1, #T_db20b_row3_col2, #T_db20b_row3_col3, #T_db20b_row3_col4, #T_db20b_row3_col5, #T_db20b_row3_col6, #T_db20b_row4_col0, #T_db20b_row4_col1, #T_db20b_row4_col2, #T_db20b_row4_col3, #T_db20b_row4_col4, #T_db20b_row4_col5, #T_db20b_row4_col6, #T_db20b_row5_col0, #T_db20b_row5_col1, #T_db20b_row5_col2, #T_db20b_row5_col3, #T_db20b_row5_col4, #T_db20b_row5_col5, #T_db20b_row5_col6, #T_db20b_row6_col0, #T_db20b_row6_col1, #T_db20b_row6_col2, #T_db20b_row6_col3, #T_db20b_row6_col4, #T_db20b_row6_col5, #T_db20b_row6_col6, #T_db20b_row7_col0, #T_db20b_row7_col1, #T_db20b_row7_col2, #T_db20b_row7_col3, #T_db20b_row7_col4, #T_db20b_row7_col5, #T_db20b_row7_col6, #T_db20b_row8_col0, #T_db20b_row8_col1, #T_db20b_row8_col2, #T_db20b_row8_col3, #T_db20b_row8_col4, #T_db20b_row8_col5, #T_db20b_row8_col6, #T_db20b_row9_col0, #T_db20b_row9_col1, #T_db20b_row9_col2, #T_db20b_row9_col3, #T_db20b_row9_col4, #T_db20b_row9_col5, #T_db20b_row9_col6, #T_db20b_row10_col0, #T_db20b_row10_col1, #T_db20b_row10_col2, #T_db20b_row10_col3, #T_db20b_row10_col4, #T_db20b_row10_col5, #T_db20b_row10_col6, #T_db20b_row11_col0, #T_db20b_row11_col1, #T_db20b_row11_col2, #T_db20b_row11_col3, #T_db20b_row11_col4, #T_db20b_row11_col5, #T_db20b_row11_col6, #T_db20b_row12_col0, #T_db20b_row12_col1, #T_db20b_row12_col2, #T_db20b_row12_col3, #T_db20b_row12_col4, #T_db20b_row12_col5, #T_db20b_row12_col6, #T_db20b_row13_col0, #T_db20b_row13_col1, #T_db20b_row13_col2, #T_db20b_row13_col3, #T_db20b_row13_col4, #T_db20b_row13_col5, #T_db20b_row13_col6, #T_db20b_row14_col0, #T_db20b_row14_col1, #T_db20b_row14_col2, #T_db20b_row14_col3, #T_db20b_row14_col4, #T_db20b_row14_col5, #T_db20b_row14_col6, #T_db20b_row15_col0, #T_db20b_row15_col1, #T_db20b_row15_col2, #T_db20b_row15_col3, #T_db20b_row15_col4, #T_db20b_row15_col5, #T_db20b_row15_col6, #T_db20b_row16_col0, #T_db20b_row16_col1, #T_db20b_row16_col2, #T_db20b_row16_col3, #T_db20b_row16_col4, #T_db20b_row16_col5, #T_db20b_row16_col6, #T_db20b_row17_col0, #T_db20b_row17_col1, #T_db20b_row17_col2, #T_db20b_row17_col3, #T_db20b_row17_col4, #T_db20b_row17_col5, #T_db20b_row17_col6, #T_db20b_row18_col0, #T_db20b_row18_col1, #T_db20b_row18_col2, #T_db20b_row18_col3, #T_db20b_row18_col4, #T_db20b_row18_col5, #T_db20b_row18_col6 {
#   text-align: left;
# }
# #T_db20b_row0_col2, #T_db20b_row0_col4, #T_db20b_row1_col1, #T_db20b_row1_col3, #T_db20b_row1_col5, #T_db20b_row1_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_db20b_row0_col7, #T_db20b_row1_col7, #T_db20b_row2_col7, #T_db20b_row3_col7, #T_db20b_row4_col7, #T_db20b_row5_col7, #T_db20b_row7_col7, #T_db20b_row8_col7, #T_db20b_row9_col7, #T_db20b_row10_col7, #T_db20b_row11_col7, #T_db20b_row12_col7, #T_db20b_row14_col7, #T_db20b_row16_col7, #T_db20b_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_db20b_row6_col7, #T_db20b_row13_col7, #T_db20b_row15_col7, #T_db20b_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_db20b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db20b_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_db20b_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_db20b_row0_col1" class="data row0 col1" >762.0118</td>
#       <td id="T_db20b_row0_col2" class="data row0 col2" >2763999.1585</td>
#       <td id="T_db20b_row0_col3" class="data row0 col3" >1612.2410</td>
#       <td id="T_db20b_row0_col4" class="data row0 col4" >0.9729</td>
#       <td id="T_db20b_row0_col5" class="data row0 col5" >0.0817</td>
#       <td id="T_db20b_row0_col6" class="data row0 col6" >0.0607</td>
#       <td id="T_db20b_row0_col7" class="data row0 col7" >0.3330</td>
#     </tr>
#     <tr>
#       <th id="T_db20b_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_db20b_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_db20b_row1_col1" class="data row1 col1" >708.8427</td>
#       <td id="T_db20b_row1_col2" class="data row1 col2" >2799609.2534</td>
#       <td id="T_db20b_row1_col3" class="data row1 col3" >1607.9791</td>
#       <td id="T_db20b_row1_col4" class="data row1 col4" >0.9724</td>
#       <td id="T_db20b_row1_col5" class="data row1 col5" >0.0743</td>
#       <td id="T_db20b_row1_col6" class="data row1 col6" >0.0541</td>
#       <td id="T_db20b_row1_col7" class="data row1 col7" >0.3210</td>
#     </tr>
#     <tr>
#       <th id="T_db20b_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_db20b_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_db20b_row2_col1" class="data row2 col1" >760.6304</td>
#       <td id="T_db20b_row2_col2" class="data row2 col2" >2929683.1860</td>
#       <td id="T_db20b_row2_col3" class="data row2 col3" >1663.0148</td>
#       <td id="T_db20b_row2_col4" class="data row2 col4" >0.9714</td>
#       <td id="T_db20b_row2_col5" class="data row2 col5" >0.0818</td>
#       <td id="T_db20b_row2_col6" class="data row2 col6" >0.0597</td>
#       <td id="T_db20b_row2_col7" class="data row2 col7" >0.2890</td>
#     </tr>
#     <tr>
#       <th id="T_db20b_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_db20b_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_db20b_row3_col1" class="data row3 col1" >752.6446</td>
#       <td id="T_db20b_row3_col2" class="data row3 col2" >3056347.8515</td>
#       <td id="T_db20b_row3_col3" class="data row3 col3" >1687.9907</td>
#       <td id="T_db20b_row3_col4" class="data row3 col4" >0.9711</td>
#       <td id="T_db20b_row3_col5" class="data row3 col5" >0.0773</td>
#       <td id="T_db20b_row3_col6" class="data row3 col6" >0.0567</td>
#       <td id="T_db20b_row3_col7" class="data row3 col7" >0.0560</td>
#     </tr>
#     <tr>
#       <th id="T_db20b_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_db20b_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_db20b_row4_col1" class="data row4 col1" >920.2913</td>
#       <td id="T_db20b_row4_col2" class="data row4 col2" >3764303.9252</td>
#       <td id="T_db20b_row4_col3" class="data row4 col3" >1901.1793</td>
#       <td id="T_db20b_row4_col4" class="data row4 col4" >0.9633</td>
#       <td id="T_db20b_row4_col5" class="data row4 col5" >0.1024</td>
#       <td id="T_db20b_row4_col6" class="data row4 col6" >0.0770</td>
#       <td id="T_db20b_row4_col7" class="data row4 col7" >0.0670</td>
#     </tr>
#     <tr>
#       <th id="T_db20b_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_db20b_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_db20b_row5_col1" class="data row5 col1" >1003.1237</td>
#       <td id="T_db20b_row5_col2" class="data row5 col2" >5305620.3379</td>
#       <td id="T_db20b_row5_col3" class="data row5 col3" >2228.7271</td>
#       <td id="T_db20b_row5_col4" class="data row5 col4" >0.9476</td>
#       <td id="T_db20b_row5_col5" class="data row5 col5" >0.1083</td>
#       <td id="T_db20b_row5_col6" class="data row5 col6" >0.0775</td>
#       <td id="T_db20b_row5_col7" class="data row5 col7" >0.0080</td>
